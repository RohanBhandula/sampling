# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Creditcard_data.csv')

# %% [markdown]
# ## accuracy

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
def RandomForest(X_train, y_train, X_test, y_test):
  clf = RandomForestClassifier(n_estimators = 2)
  clf.fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  return accuracy_score(y_test,y_pred)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
def KNN(X_train, y_train, X_test, y_test):
  knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train)
  knn_pred = knn.predict(X_test)
  return accuracy_score(y_test,knn_pred)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
def DecisionTree(X_train, y_train, X_test, y_test):
  tree = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
  tree_pred = tree.predict(X_test)
  return accuracy_score(y_test,tree_pred)

# %% [markdown]
# # Logistic

# %%
from sklearn.linear_model import LogisticRegression
def Logistic(X_train, y_train, X_test, y_test):
  clf = LogisticRegression()
  clf.fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  return accuracy_score(y_test,y_pred)

# %% [markdown]
# # SVC

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
def SVC(X_train, y_train, X_test, y_test):
  svm = SGDClassifier(loss='hinge')
  svm.fit(X_train, y_train)
  y_pred = svm.predict(X_test)
  return accuracy_score(y_test,y_pred)

# %% [markdown]
# # Normalisation of amt

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the 'Amount' column
scaler.fit(df[['Amount']])

# Transform the 'Amount' column
df['Amount'] = scaler.transform(df[['Amount']])

# Drop the first column (assuming it's the index)
df = df.iloc[:, 1:]
df
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 0   -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# ..        ...       ...       ...       ...       ...       ...       ...
# 767 -0.572263  0.731748  1.541254  0.150506  1.108974  0.372152  1.084879
# 768 -1.296845 -0.511605  2.404726 -0.310762 -0.319551 -0.542842 -0.173310
# 769  1.214170  0.210481  0.484651  0.479768 -0.261955 -0.527039  0.021782
# 770  1.267030 -0.071114  0.037680  0.512683  0.242392  0.705212 -0.226582
# 771  1.153758  0.132273  0.382969  1.405063 -0.224287 -0.197295  0.020653
#
#            V8        V9       V10  ...       V21       V22       V23  \
# 0    0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1    0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 2    0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 3    0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 4   -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# ..        ...       ...       ...  ...       ...       ...       ...
# 767 -0.146329 -0.274447 -0.663670  ... -0.143508 -0.107582 -0.418263
# 768  0.260423 -1.202688  0.050584  ... -0.071270 -0.161175  0.088496
# 769 -0.106888 -0.037631 -0.144073  ... -0.224292 -0.594609  0.159877
# 770  0.109483  0.657565 -0.276918  ... -0.164468 -0.177225 -0.222918
# 771  0.029260  0.412254 -0.103547  ... -0.107809 -0.125231 -0.057041
#
#           V24       V25       V26       V27       V28    Amount  Class
# 0    0.066928  0.128539 -0.189115  0.133558 -0.021053  0.409447      0
# 1   -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.333712      1
# 2   -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.567910      0
# 3   -1.175575  0.647376 -0.221929  0.062723  0.061458  0.277334      0
# 4    0.141267 -0.206010  0.502292  0.219422  0.215153  0.006685      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 767 -0.731029  0.877525 -0.364150 -0.177509 -0.256545 -0.212171      0
# 768  0.285390  0.281069 -0.370130  0.043410  0.092318  0.057315      0
# 769  0.091873  0.140964  0.227406 -0.017389  0.016030 -0.317072      0
# 770 -1.245505  0.678360  0.525059  0.002920 -0.003333 -0.284802      0
# 771  0.073082  0.633977 -0.310685  0.033590  0.015250 -0.277569      0
#
# [772 rows x 30 columns]

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from imblearn.under_sampling import RandomUnderSampler
####OVER SAMPLER#####
# create the RandomOverSampler object
# ros = RandomOverSampler()

# # perform random oversampling on the original dataset
# X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# # print the shapes of the original and resampled datasets
# print("Original dataset shape:", X_train.shape, y_train.shape)
# print("Resampled dataset shape:", X_train_resampled.shape, y_train_resampled.shape)


# create the RandomUnderSampler object
rus = RandomUnderSampler()

# perform under-sampling on the original dataset
X_train_resampled, y_train_resampled = rus.fit_resample(X, y)

# print the shapes of the original and resampled datasets
print("Original dataset shape:", X.shape, y.shape)
print("Resampled dataset shape:", X_train_resampled.shape, y_train_resampled.shape)
X_train_resampled
# Out:
# Original dataset shape: (772, 29) (772,)
# Resampled dataset shape: (18, 29) (18,)
#           V1        V2        V3        V4        V5        V6        V7  \
# 0   0.270725 -1.615317  1.054982  1.661510 -1.737687  0.065894 -0.313977
# 1   0.071936 -1.601999 -0.606193  1.591623 -0.364290  0.319968  0.856676
# 2  -0.378245  0.732925 -0.120154  0.185755  2.594269  3.797183  0.059088
# 3  -0.571521  1.071600  1.280110  0.542780  0.574439 -0.259359  1.061148
# 4  -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
# 5  -0.433211  1.020835  2.019730  3.003261  0.031308  0.187063  0.850856
# 6   1.331897 -0.579962  0.422606 -0.897752 -0.746254 -0.056273 -0.750317
# 7  -0.378489  0.532043  1.498352 -1.451159  0.245405 -0.648925  0.849375
# 8  -0.420050  1.034648  1.565850 -0.029643 -0.054336 -0.907983  0.688436
# 9   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 10  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 11  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# 12 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 13 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 14 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 15 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 16 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
# 17  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481  0.094272
#
#           V8        V9       V10  ...       V20       V21       V22       V23  \
# 0   0.089081  1.069842 -0.348638  ...  0.754994  0.475338  0.496083 -0.482194
# 1  -0.052634 -0.188426 -0.132816  ...  0.959559  0.364078 -0.110442 -0.669058
# 2   0.976768 -0.412661  0.006754  ...  0.315572 -0.107582 -0.157140 -0.194659
# 3  -0.410972 -0.179130  1.003501  ...  0.354731  0.003559  0.561240 -0.199287
# 4   0.317761  0.593762 -0.987304  ...  0.157201 -0.197635 -0.436535 -0.194840
# 5  -0.143932 -0.918043  0.886323  ...  0.471103 -0.177298 -0.180260  0.007760
# 6   0.128484 -0.964682  0.736391  ...  0.052489 -0.039070 -0.255174  0.109333
# 7  -0.159859 -0.194442 -0.484103  ... -0.088347 -0.036825 -0.083855 -0.184519
# 8  -0.063128 -0.389635 -0.308594  ...  0.095869 -0.228282 -0.598231 -0.023081
# 9   0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 10 -0.202836  0.035154 -0.282617  ... -0.079756 -0.287592 -0.832682  0.128083
# 11  0.139497 -0.123050 -0.142617  ... -0.043920 -0.128758 -0.381932  0.151012
# 12  1.391657 -2.770089 -2.772272  ...  0.126911  0.517232 -0.035049 -0.465211
# 13 -0.067794 -0.270953 -0.838587  ...  2.102339  0.661696  0.435477  1.375966
# 14 -0.156590 -0.142117 -0.574775  ... -0.118283  0.066353  0.281378 -0.257966
# 15  0.788347  0.958809 -0.328631  ...  0.620899  0.422452  1.195394  0.297836
# 16  0.140631  0.023464 -0.066407  ...  0.002974 -0.179545 -0.192036 -0.261879
# 17 -0.210300  0.014455 -0.286012  ... -0.073779 -0.286856 -0.820658  0.127663
#
#          V24       V25       V26       V27       V28    Amount
# 0   0.418871  0.235961 -0.265185 -0.001063  0.120126  1.976236
# 1  -0.262152  0.555656 -0.288130 -0.089500  0.095584  2.562650
# 2   1.013897  0.145503 -0.237620  0.411372  0.202788 -0.289405
# 3   0.001387 -0.179530 -0.374116  0.071641 -0.175510 -0.297801
# 4  -1.236873  0.218668  0.902383 -0.210195 -0.190458  0.122157
# 5   0.382658 -0.187193  0.100067  0.204039 -0.018150 -0.017239
# 6  -0.328448  0.162254 -0.447276  0.020071  0.006231 -0.274080
# 7   0.032645 -0.396424  0.722854 -0.165667 -0.124331 -0.308423
# 8   0.360199 -0.194316  0.071640  0.265159  0.121071 -0.340793
# 9  -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.333712
# 10  0.339427  0.215944  0.094704 -0.023354  0.030892 -0.333712
# 11 -1.363967 -1.389079  0.075412  0.231750  0.230171 -0.342311
# 12  0.320198  0.044519  0.177840  0.261145 -0.143276 -0.347318
# 13 -0.293803  0.279798 -0.145362 -0.252773  0.035764  2.328317
# 14  0.385384  0.391117 -0.453853 -0.104448 -0.125765 -0.342260
# 15 -0.857105 -0.219322  0.861019 -0.124622 -0.171060 -0.339731
# 16 -0.237477 -0.335040  0.240323 -0.345129 -0.383563 -0.342260
# 17  0.343128  0.221120  0.094391 -0.022189  0.030944 -0.340793
#
# [18 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
X_dummy, X_test, y_dummy, y_test = train_test_split(X_train_resampled, y_train_resampled, test_size=0.4, random_state=42)

# %%
dfnew = pd.concat([X_train_resampled,y_train_resampled ], axis=1)
dfnew
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0   0.270725 -1.615317  1.054982  1.661510 -1.737687  0.065894 -0.313977
# 1   0.071936 -1.601999 -0.606193  1.591623 -0.364290  0.319968  0.856676
# 2  -0.378245  0.732925 -0.120154  0.185755  2.594269  3.797183  0.059088
# 3  -0.571521  1.071600  1.280110  0.542780  0.574439 -0.259359  1.061148
# 4  -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
# 5  -0.433211  1.020835  2.019730  3.003261  0.031308  0.187063  0.850856
# 6   1.331897 -0.579962  0.422606 -0.897752 -0.746254 -0.056273 -0.750317
# 7  -0.378489  0.532043  1.498352 -1.451159  0.245405 -0.648925  0.849375
# 8  -0.420050  1.034648  1.565850 -0.029643 -0.054336 -0.907983  0.688436
# 9   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 10  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 11  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# 12 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 13 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 14 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 15 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 16 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
# 17  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481  0.094272
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 0   0.089081  1.069842 -0.348638  ...  0.475338  0.496083 -0.482194  0.418871
# 1  -0.052634 -0.188426 -0.132816  ...  0.364078 -0.110442 -0.669058 -0.262152
# 2   0.976768 -0.412661  0.006754  ... -0.107582 -0.157140 -0.194659  1.013897
# 3  -0.410972 -0.179130  1.003501  ...  0.003559  0.561240 -0.199287  0.001387
# 4   0.317761  0.593762 -0.987304  ... -0.197635 -0.436535 -0.194840 -1.236873
# 5  -0.143932 -0.918043  0.886323  ... -0.177298 -0.180260  0.007760  0.382658
# 6   0.128484 -0.964682  0.736391  ... -0.039070 -0.255174  0.109333 -0.328448
# 7  -0.159859 -0.194442 -0.484103  ... -0.036825 -0.083855 -0.184519  0.032645
# 8  -0.063128 -0.389635 -0.308594  ... -0.228282 -0.598231 -0.023081  0.360199
# 9   0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 10 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083  0.339427
# 11  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012 -1.363967
# 12  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211  0.320198
# 13 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966 -0.293803
# 14 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966  0.385384
# 15  0.788347  0.958809 -0.328631  ...  0.422452  1.195394  0.297836 -0.857105
# 16  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879 -0.237477
# 17 -0.210300  0.014455 -0.286012  ... -0.286856 -0.820658  0.127663  0.343128
#
#          V25       V26       V27       V28    Amount  Class
# 0   0.235961 -0.265185 -0.001063  0.120126  1.976236      0
# 1   0.555656 -0.288130 -0.089500  0.095584  2.562650      0
# 2   0.145503 -0.237620  0.411372  0.202788 -0.289405      0
# 3  -0.179530 -0.374116  0.071641 -0.175510 -0.297801      0
# 4   0.218668  0.902383 -0.210195 -0.190458  0.122157      0
# 5  -0.187193  0.100067  0.204039 -0.018150 -0.017239      0
# 6   0.162254 -0.447276  0.020071  0.006231 -0.274080      0
# 7  -0.396424  0.722854 -0.165667 -0.124331 -0.308423      0
# 8  -0.194316  0.071640  0.265159  0.121071 -0.340793      0
# 9   0.167170  0.125895 -0.008983  0.014724 -0.333712      1
# 10  0.215944  0.094704 -0.023354  0.030892 -0.333712      1
# 11 -1.389079  0.075412  0.231750  0.230171 -0.342311      1
# 12  0.044519  0.177840  0.261145 -0.143276 -0.347318      1
# 13  0.279798 -0.145362 -0.252773  0.035764  2.328317      1
# 14  0.391117 -0.453853 -0.104448 -0.125765 -0.342260      1
# 15 -0.219322  0.861019 -0.124622 -0.171060 -0.339731      1
# 16 -0.335040  0.240323 -0.345129 -0.383563 -0.342260      1
# 17  0.221120  0.094391 -0.022189  0.030944 -0.340793      1
#
# [18 rows x 30 columns]

# %% [markdown]
# # simple

# %%
import random

# select a convenience sample
sample_df = dfnew.sample(n=5)

# print the resulting sample DataFrame
print(sample_df)
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 14 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 3  -0.571521  1.071600  1.280110  0.542780  0.574439 -0.259359  1.061148
# 15 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 10  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 13 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 14 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966  0.385384
# 3  -0.410972 -0.179130  1.003501  ...  0.003559  0.561240 -0.199287  0.001387
# 15  0.788347  0.958809 -0.328631  ...  0.422452  1.195394  0.297836 -0.857105
# 10 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083  0.339427
# 13 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966 -0.293803
#
#          V25       V26       V27       V28    Amount  Class
# 14  0.391117 -0.453853 -0.104448 -0.125765 -0.342260      1
# 3  -0.179530 -0.374116  0.071641 -0.175510 -0.297801      0
# 15 -0.219322  0.861019 -0.124622 -0.171060 -0.339731      1
# 10  0.215944  0.094704 -0.023354  0.030892 -0.333712      1
# 13  0.279798 -0.145362 -0.252773  0.035764  2.328317      1
#
# [5 rows x 30 columns]

# %%
SimpleX = sample_df.drop('Class', axis=1) 
Simpley = sample_df['Class']

# %%
simpleKNN = KNN(SimpleX,Simpley,X_test,y_test)
simplelogistic = Logistic(SimpleX,Simpley,X_test,y_test)
simpleRandomForest = RandomForest(SimpleX,Simpley,X_test,y_test)
simpleDecisionTree = DecisionTree(SimpleX,Simpley,X_test,y_test)
simplesvc = SVC(SimpleX,Simpley,X_test,y_test)

final1 = [simpleRandomForest,simpleDecisionTree,simpleKNN,simplelogistic,simplesvc]
final1
# Out:
# c:\Users\aa\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [0.375, 0.75, 0.375, 0.5, 0.5]

# %% [markdown]
# # stratified

# %%
strat = dfnew.groupby('Class', group_keys=False).apply(lambda x: x.sample(5))
strat
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0   0.270725 -1.615317  1.054982  1.661510 -1.737687  0.065894 -0.313977
# 2  -0.378245  0.732925 -0.120154  0.185755  2.594269  3.797183  0.059088
# 8  -0.420050  1.034648  1.565850 -0.029643 -0.054336 -0.907983  0.688436
# 4  -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
# 6   1.331897 -0.579962  0.422606 -0.897752 -0.746254 -0.056273 -0.750317
# 14 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 9   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 17  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481  0.094272
# 15 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 11  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 0   0.089081  1.069842 -0.348638  ...  0.475338  0.496083 -0.482194  0.418871
# 2   0.976768 -0.412661  0.006754  ... -0.107582 -0.157140 -0.194659  1.013897
# 8  -0.063128 -0.389635 -0.308594  ... -0.228282 -0.598231 -0.023081  0.360199
# 4   0.317761  0.593762 -0.987304  ... -0.197635 -0.436535 -0.194840 -1.236873
# 6   0.128484 -0.964682  0.736391  ... -0.039070 -0.255174  0.109333 -0.328448
# 14 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966  0.385384
# 9   0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 17 -0.210300  0.014455 -0.286012  ... -0.286856 -0.820658  0.127663  0.343128
# 15  0.788347  0.958809 -0.328631  ...  0.422452  1.195394  0.297836 -0.857105
# 11  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012 -1.363967
#
#          V25       V26       V27       V28    Amount  Class
# 0   0.235961 -0.265185 -0.001063  0.120126  1.976236      0
# 2   0.145503 -0.237620  0.411372  0.202788 -0.289405      0
# 8  -0.194316  0.071640  0.265159  0.121071 -0.340793      0
# 4   0.218668  0.902383 -0.210195 -0.190458  0.122157      0
# 6   0.162254 -0.447276  0.020071  0.006231 -0.274080      0
# 14  0.391117 -0.453853 -0.104448 -0.125765 -0.342260      1
# 9   0.167170  0.125895 -0.008983  0.014724 -0.333712      1
# 17  0.221120  0.094391 -0.022189  0.030944 -0.340793      1
# 15 -0.219322  0.861019 -0.124622 -0.171060 -0.339731      1
# 11 -1.389079  0.075412  0.231750  0.230171 -0.342311      1
#
# [10 rows x 30 columns]

# %%
stratX = strat.drop('Class', axis=1) #X_train
straty = strat['Class'] #y_train

stratRandomForest = RandomForest(stratX,straty,X_test,y_test)
stratDecisionTree = DecisionTree(stratX,straty,X_test,y_test)
stratKNN = KNN(stratX,straty,X_test,y_test)
stratlogistic = Logistic(stratX,straty,X_test,y_test)
stratsvc = SVC(stratX,straty,X_test,y_test)

final2 = [stratRandomForest,stratDecisionTree,stratKNN,stratlogistic,stratsvc]
final2
# Out:
# c:\Users\aa\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [0.75, 1.0, 0.5, 0.75, 0.875]

# %% [markdown]
# # cluster

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# select the features and target variable
X = dfnew
y = dfnew['Class']

# perform k-means clustering on the features
kmeans = KMeans(n_clusters=5, random_state=42).fit(X)
cluster_labels = kmeans.labels_

# create a DataFrame with the cluster labels and the target variable
cluster_df = pd.DataFrame({'cluster': cluster_labels, 'target': y})

# select a random sample of clusters
sample_clusters = np.random.choice(cluster_df['cluster'].unique(), size=5, replace=False)

# retrieve the observations from the selected clusters
sample_df = dfnew.loc[cluster_df['cluster'].isin(sample_clusters)]

# print the resulting sample DataFrame
print(sample_df.head())
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.270725 -1.615317  1.054982  1.661510 -1.737687  0.065894 -0.313977
# 1  0.071936 -1.601999 -0.606193  1.591623 -0.364290  0.319968  0.856676
# 2 -0.378245  0.732925 -0.120154  0.185755  2.594269  3.797183  0.059088
# 3 -0.571521  1.071600  1.280110  0.542780  0.574439 -0.259359  1.061148
# 4 -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.089081  1.069842 -0.348638  ...  0.475338  0.496083 -0.482194  0.418871
# 1 -0.052634 -0.188426 -0.132816  ...  0.364078 -0.110442 -0.669058 -0.262152
# 2  0.976768 -0.412661  0.006754  ... -0.107582 -0.157140 -0.194659  1.013897
# 3 -0.410972 -0.179130  1.003501  ...  0.003559  0.561240 -0.199287  0.001387
# 4  0.317761  0.593762 -0.987304  ... -0.197635 -0.436535 -0.194840 -1.236873
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.235961 -0.265185 -0.001063  0.120126  1.976236      0
# 1  0.555656 -0.288130 -0.089500  0.095584  2.562650      0
# 2  0.145503 -0.237620  0.411372  0.202788 -0.289405      0
# 3 -0.179530 -0.374116  0.071641 -0.175510 -0.297801      0
# 4  0.218668  0.902383 -0.210195 -0.190458  0.122157      0
#
# [5 rows x 30 columns]

# %%
clusterX = sample_df.drop('Class', axis=1) #X_train
clustery = sample_df['Class'] #y_train

clusterRandomForest = RandomForest(clusterX,clustery,X_test,y_test)
clusterDecisionTree = DecisionTree(clusterX,clustery,X_test,y_test)
clusterKNN = KNN(clusterX,clustery,X_test,y_test)
clusterlogistic = Logistic(clusterX,clustery,X_test,y_test)
clustersvc = SVC(clusterX,clustery,X_test,y_test)

final3 = [clusterRandomForest,clusterDecisionTree,clusterKNN,clusterlogistic,clustersvc]
final3
# Out:
# c:\Users\aa\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [0.75, 1.0, 0.625, 1.0, 1.0]

# %% [markdown]
# # systematic

# %%
# set the sampling interval
k = 4

# compute the number of samples
n = len(dfnew)

# compute the number of groups
num_groups = int(np.ceil(n / k))

# generate a list of starting indices for each group
start_indices = [i * k for i in range(num_groups)]

# retrieve the sample using systematic sampling
sample_df = dfnew.iloc[start_indices]

# print the resulting sample DataFrame
print(sample_df)
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0   0.270725 -1.615317  1.054982  1.661510 -1.737687  0.065894 -0.313977
# 4  -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
# 8  -0.420050  1.034648  1.565850 -0.029643 -0.054336 -0.907983  0.688436
# 12 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 16 -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788  0.269083
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 0   0.089081  1.069842 -0.348638  ...  0.475338  0.496083 -0.482194  0.418871
# 4   0.317761  0.593762 -0.987304  ... -0.197635 -0.436535 -0.194840 -1.236873
# 8  -0.063128 -0.389635 -0.308594  ... -0.228282 -0.598231 -0.023081  0.360199
# 12  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211  0.320198
# 16  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036 -0.261879 -0.237477
#
#          V25       V26       V27       V28    Amount  Class
# 0   0.235961 -0.265185 -0.001063  0.120126  1.976236      0
# 4   0.218668  0.902383 -0.210195 -0.190458  0.122157      0
# 8  -0.194316  0.071640  0.265159  0.121071 -0.340793      0
# 12  0.044519  0.177840  0.261145 -0.143276 -0.347318      1
# 16 -0.335040  0.240323 -0.345129 -0.383563 -0.342260      1
#
# [5 rows x 30 columns]

# %%
systematicX = sample_df.drop('Class', axis=1) #X_train
systematicy = sample_df['Class'] #y_train

systematicRandomForest = RandomForest(systematicX,systematicy,X_test,y_test)
systematicDecisionTree = DecisionTree(systematicX,systematicy,X_test,y_test)
systematicKNN = KNN(systematicX,systematicy,X_test,y_test)
systematiclogistic = Logistic(systematicX,systematicy,X_test,y_test)
systematicsvc = SVC(systematicX,systematicy,X_test,y_test)

final4 = [systematicRandomForest,systematicDecisionTree,systematicKNN,systematiclogistic,systematicsvc]
final4
# Out:
# c:\Users\aa\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [0.625, 0.5, 0.625, 0.875, 0.625]

# %% [markdown]
# # convenience

# %%
import random

# select a convenience sample
sample_df = dfnew.sample(n=5)

# print the resulting sample DataFrame
print(sample_df)
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 15 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 4  -0.860626 -0.109137  2.112474 -1.400567  0.180269  1.329656  0.431001
# 2  -0.378245  0.732925 -0.120154  0.185755  2.594269  3.797183  0.059088
# 12 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 13 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# 15  0.788347  0.958809 -0.328631  ...  0.422452  1.195394  0.297836 -0.857105
# 4   0.317761  0.593762 -0.987304  ... -0.197635 -0.436535 -0.194840 -1.236873
# 2   0.976768 -0.412661  0.006754  ... -0.107582 -0.157140 -0.194659  1.013897
# 12  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211  0.320198
# 13 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966 -0.293803
#
#          V25       V26       V27       V28    Amount  Class
# 15 -0.219322  0.861019 -0.124622 -0.171060 -0.339731      1
# 4   0.218668  0.902383 -0.210195 -0.190458  0.122157      0
# 2   0.145503 -0.237620  0.411372  0.202788 -0.289405      0
# 12  0.044519  0.177840  0.261145 -0.143276 -0.347318      1
# 13  0.279798 -0.145362 -0.252773  0.035764  2.328317      1
#
# [5 rows x 30 columns]

# %%
convenienceX = sample_df.drop('Class', axis=1) #X_train
conveniencey= sample_df['Class'] #y_train

convenienceRandomForest = RandomForest(convenienceX,conveniencey,X_test,y_test)
convenienceDecisionTree = DecisionTree(convenienceX,conveniencey,X_test,y_test)
convenienceKNN = KNN(convenienceX,conveniencey,X_test,y_test)
conveniencelogistic = Logistic(convenienceX,conveniencey,X_test,y_test)
conveniencesvc = SVC(convenienceX,conveniencey,X_test,y_test)

final5 = [convenienceRandomForest,convenienceDecisionTree,convenienceKNN,conveniencelogistic,conveniencesvc]
final5
# Out:
# c:\Users\aa\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [0.5, 0.5, 0.375, 0.75, 0.75]

# %% [markdown]
# # final

# %%
data = {
    'Model' : ['Random Forest','Decision Tree','KNN','Logistic Regression','SVC'],'Stratified' : final2, 'Simple' : final1,'Systematic' : final4,'Cluster' : final3,'Convenience' : final5
}
     

final_df = pd.DataFrame(data)

final_df
# Out:
#                  Model  Stratified  Simple  Systematic  Cluster  Convenience
# 0        Random Forest       0.750   0.375       0.625    0.750        0.500
# 1        Decision Tree       1.000   0.750       0.500    1.000        0.500
# 2                  KNN       0.500   0.375       0.625    0.625        0.375
# 3  Logistic Regression       0.750   0.500       0.875    1.000        0.750
# 4                  SVC       0.875   0.500       0.625    1.000        0.750
